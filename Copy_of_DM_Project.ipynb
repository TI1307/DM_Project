# %% [markdown]
# <a href="https://colab.research.google.com/github/TI1307/DM_Project/blob/main/Copy_of_DM_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %% [markdown]
# # Data Preprocessing and cleaning

# %% [markdown]
# # 4.1 Data Quality **Issues**

# %%
import pandas as pd
########LIBRARY INVENTORY TABLE ###############
LIBRARY_INVENTORY= pd.read_excel("LIBRARY INVENTORY.xlsx")
print ('Number of instance in the LIBRARY INVENTORY' , (LIBRARY_INVENTORY.shape[0]))
print ('Number of attributes in the LIBRARY INVENTORY' , (LIBRARY_INVENTORY.shape[1]))
print ('#####################################################')
########LIBRARY_CARALOGUE TABLE ###############
LIBRARY_CARALOGUE= pd.read_excel("library catalogue.xlsx")
print ('Number of instance in the LIBRARY CARALOGUE' , (LIBRARY_CARALOGUE.shape[0]))
print ('Number of attributes in the LIBRARY INVENTORY' , (LIBRARY_CARALOGUE.shape[1]))
print ('#####################################################')
#######BORROWING TABLE ###########################
BORROWINGS= pd.read_excel("Borrowings.xlsx")
print ('Number of instance in the BORROWINGS TABLE ' , (BORROWINGS.shape[0]))
print ('Number of attributes in the BORROWINGS TABLE ' , (BORROWINGS.shape[1]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3344572663.py in <cell line: 0>()
#       1 import pandas as pd
#       2 ########LIBRARY INVENTORY TABLE ###############
# ----> 3 LIBRARY_INVENTORY= pd.read_excel("LIBRARY INVENTORY.xlsx")
#       4 print ('Number of instance in the LIBRARY INVENTORY' , (LIBRARY_INVENTORY.shape[0]))
#       5 print ('Number of attributes in the LIBRARY INVENTORY' , (LIBRARY_INVENTORY.shape[1]))
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
# ...

# %% [markdown]
# # **4.1.1 Missing Values**

# %% [markdown]
# # **4.1.2 Outliers**

# %% [markdown]
# # **4.1.3 Duplicate Data**

# %%
dups = LIBRARY_INVENTORY.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

# %% [markdown]
# # **4.2 Aggregation**

# %% [markdown]
# # **4.3 Sampling**

# %% [markdown]
# # **4.4 Discretization**
