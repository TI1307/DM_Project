# %% [markdown]
# ## **Association Rules**

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth
from mlxtend.frequent_patterns import association_rules

# %%
Borrowings_Table=pd.read_excel("../data/cleaned_borrowings.xlsx")

# %%
Borrowings_Table.head()
# Out:
#    Numéro           Cote  \
# 0    1000        515 MON
# 1    1005      510.BAL/1
# 2    1006      510.BAL/2
# 3    1007      510.BAL/3
# 4    1009  518.107.BAY/1
#
#                                                                                                                    Titre  \
# 0                                                                          Exercices corrigés d'analyse : 1ère année LMD
# 1  Exercices d'algèbre et d'analyse : 154 exercices corrigés de premiére année 21 édition entiérement revue et augmentée
# 2  Exercices d'algèbre et d'analyse : 154 exercices corrigés de premiére année 21 édition entiérement revue et augmentée
# 3  Exercices d'algèbre et d'analyse : 154 exercices corrigés de premiére année 21 édition entiérement revue et augmentée
# 4                                         Exercices et problèmes d'algorithmique : 144 énoncés avec solutions détaillées
#
#   Type de document N° lecteur        Nom       Prénom    Catégorie  \
# 0            Livre    5817912    MAMECHE       FERIEL  1 ére ANNEE
# 1            Livre    5754033    fourali        malak  1 ére ANNEE
# 2            Livre    5113394     SEHALI         MAYA  1 ére ANNEE
# 3            Livre    6092419  kheddaoui      thiziri  1 ére ANNEE
# 4            Livre    8354464      GACEB  RIHAM BAHIA  3 ème ANNEE
#
#                                                                                                            Titre_clean  \
# 0                                                                          EXERCICES CORRIGES D ANALYSE 1ERE ANNEE LMD
# 1  EXERCICES D ALGEBRE ET D ANALYSE 154 EXERCICES CORRIGES DE PREMIERE ANNEE 21 EDITION ENTIEREMENT REVUE ET AUGMENTEE
# 2  EXERCICES D ALGEBRE ET D ANALYSE 154 EXERCICES CORRIGES DE PREMIERE ANNEE 21 EDITION ENTIEREMENT REVUE ET AUGMENTEE
# 3  EXERCICES D ALGEBRE ET D ANALYSE 154 EXERCICES CORRIGES DE PREMIERE ANNEE 21 EDITION ENTIEREMENT REVUE ET AUGMENTEE
# 4                                         EXERCICES ET PROBLEMES D ALGORITHMIQUE 144 ENONCES AVEC SOLUTIONS DETAILLEES
#
#    borrowing duration
# 0                  15
# 1                  17
# 2                  15
# 3                  15
# 4                   7

# %%
Borrowings_Table.shape
# Out:
# (422, 10)

# %%
Borrowings_transactions = Borrowings_Table.groupby("N° lecteur")["Titre_clean"].apply(list).reset_index()

# %%
Borrowings_transactions.head()
# Out:
#   N° lecteur  \
# 0          3
# 1          4
# 2          8
# 3         24
# 4         32
#
#                                                                                                                                                                                          Titre_clean
# 0                                                                                                                         [FORMULES DE TAYLOR DEVELOPPEMENTS LIMITES L1 L2 L3 CLASSES PREPARATOIRES]
# 1                                                      [MATHEMATICAL LOGIC, LOGIQUE MATHEMATIQUE COURS ET EXERCICES CORRIGES, 400 EXERCICES CORRIGES D ALGEBRE AVEC RAPPELS DE COURS POUR SPE MP MP]
# 2                                                                                                                                                                       [INITIATION L ALGORITHMIQUE]
# 3                                                                                                                                 [BIG DATA ANALYTICS WITH APPLICATIONS IN INSIDER THREAT DETECTION]
# 4  [COMPUTER ORGANIZATION AND ARCHITECTURE DESIGNING FOR PERFORMANCE GLOBAL EDITION, CAMBRIDGE ENGLISH SKILLS REAL LISTENING AND SPEAKING 1, CAMBRIDGE ENGLISH SKILLS REAL LISTENING AND SPEAKING 2]

# %%
print("Number of transactions:", len(Borrowings_transactions))
print("Number of distinct customers:", len(list(set(Borrowings_transactions["N° lecteur"]))))
# Out:
# Number of transactions: 271
# Number of distinct customers: 271

# %%
transactions = Borrowings_transactions["Titre_clean"].tolist()
transactions[:5]
# Out:
# [['FORMULES DE TAYLOR DEVELOPPEMENTS LIMITES L1 L2 L3 CLASSES PREPARATOIRES'],
#  ['MATHEMATICAL LOGIC',
#   'LOGIQUE MATHEMATIQUE COURS ET EXERCICES CORRIGES',
#   '400 EXERCICES CORRIGES D ALGEBRE AVEC RAPPELS DE COURS POUR SPE MP MP'],
#  ['INITIATION L ALGORITHMIQUE'],
#  ['BIG DATA ANALYTICS WITH APPLICATIONS IN INSIDER THREAT DETECTION'],
#  ['COMPUTER ORGANIZATION AND ARCHITECTURE DESIGNING FOR PERFORMANCE GLOBAL EDITION',
#   'CAMBRIDGE ENGLISH SKILLS REAL LISTENING AND SPEAKING 1',
#   'CAMBRIDGE ENGLISH SKILLS REAL LISTENING AND SPEAKING 2']]

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
borrowing_df = pd.DataFrame(te_ary, columns=te.columns_)
borrowing_df
# Out:
#      400 EXERCICES CORRIGES D ALGEBRE AVEC RAPPELS DE COURS POUR SPE MP MP  \
# 0                                                                    False
# 1                                                                     True
# 2                                                                    False
# 3                                                                    False
# 4                                                                    False
# ..                                                                     ...
# 266                                                                  False
# 267                                                                  False
# 268                                                                  False
# 269                                                                  False
# 270                                                                  False
#
#      A FIRST COURSE IN PROBABILITY  ADVANCED CYBERSECURITY TECHNOLOGIES  \
# 0                            False                                False
# 1                            False                                False
# 2                            False                                False
# 3                            False                                False
# 4                            False                                False
# ..                             ...                                  ...
# 266                          False                                False
# 267                          False                                False
# 268                          False                                False
# 269                          False                                False
# 270                          False                                False
#
#      ADVANCED DATA STRUCTURES THEORY AND APPLICATIONS  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ..                                                ...
# 266                                             False
# 267                                             False
# 268                                             False
# 269                                             False
# 270                                             False
#
#      AGILE STRATEGY MANAGEMENT TECHNIQUES FOR CONTINUOUS ALIGNMENT AND IMPROVEMENT  \
# 0                                                                            False
# 1                                                                            False
# 2                                                                            False
# 3                                                                            False
# 4                                                                            False
# ..                                                                             ...
# 266                                                                          False
# 267                                                                          False
# 268                                                                          False
# 269                                                                          False
# 270                                                                           True
#
#      ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS  \
# 0                                                     False
# 1                                                     False
# 2                                                     False
# 3                                                     False
# 4                                                     False
# ..                                                      ...
# 266                                                   False
# 267                                                   False
# 268                                                    True
# 269                                                   False
# 270                                                   False
#
#      ALGEBRE 1RE ANNEE  \
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ..                 ...
# 266               True
# 267              False
# 268              False
# 269              False
# 270              False
#
#      ALGEBRE 240 EXERCICES CORRIGES AVEC RESUMES DE COURS PREMIERS CYCLES DE L ENSEIGNEMENT SUPERIEUR  \
# 0                                                                                               False
# 1                                                                                               False
# 2                                                                                               False
# 3                                                                                               False
# 4                                                                                               False
# ..                                                                                                ...
# 266                                                                                             False
# 267                                                                                             False
# 268                                                                                             False
# 269                                                                                             False
# 270                                                                                             False
#
#      ALGEBRE COURS ET EXERCICES AVEC SOLUTIONS  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 266                                      False
# 267                                      False
# 268                                      False
# 269                                      False
# 270                                      False
#
#      ALGEBRE ET GEOMETRIE 200 EXERCICES DEVELOPPES 980EXERCICES D ENTRAONEMENT RAPPELS DE COURS  \
# 0                                                                                         False
# 1                                                                                         False
# 2                                                                                         False
# 3                                                                                         False
# 4                                                                                         False
# ..                                                                                          ...
# 266                                                                                       False
# 267                                                                                       False
# 268                                                                                       False
# 269                                                                                       False
# 270                                                                                       False
#
#      ALGEBRE GENERALE RAPPELS DE COURS QUESTIONS DE REFLEXION EXERCICES D ENTRAINEMENT  \
# 0                                                                                False
# 1                                                                                False
# 2                                                                                False
# 3                                                                                False
# 4                                                                                False
# ..                                                                                 ...
# 266                                                                              False
# 267                                                                              False
# 268                                                                              False
# 269                                                                              False
# 270                                                                              False
#
#      ALGEBRE PREMIERS PAS EN PREPA 1RE ANNEE PREPA SCIENTIFIQUE MATHEMATIQUES  \
# 0                                                                       False
# 1                                                                       False
# 2                                                                       False
# 3                                                                       False
# 4                                                                       False
# ..                                                                        ...
# 266                                                                     False
# 267                                                                     False
# 268                                                                     False
# 269                                                                     False
# 270                                                                     False
#
#      ALGEBRE RAPPELS DE COURS QUESTIONS DE REFLEXION EXERCICE D ENTRAINEMENT ANNALES CORRIGEES  \
# 0                                                                                        False
# 1                                                                                        False
# 2                                                                                        False
# 3                                                                                        False
# 4                                                                                        False
# ..                                                                                         ...
# 266                                                                                      False
# 267                                                                                      False
# 268                                                                                      False
# 269                                                                                      False
# 270                                                                                      False
#
#      ALGORITHMIQUE COURS ET EXERCICES CORRIGES  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 266                                      False
# 267                                      False
# 268                                      False
# 269                                      False
# 270                                      False
#
#      ALGORITHMIQUE ET PROGRAMMATION EN JAVA COURS ET EXERCICES  \
# 0                                                        False
# 1                                                        False
# 2                                                        False
# 3                                                        False
# 4                                                        False
# ..                                                         ...
# 266                                                      False
# 267                                                      False
# 268                                                      False
# 269                                                      False
# 270                                                      False
#
#      ALGORITHMIQUE ET STRUCTURES DE DONNEES STATIQUES COURS ET EXERCICES AVEC SOLUTIONS  \
# 0                                                                                 False
# 1                                                                                 False
# 2                                                                                 False
# 3                                                                                 False
# 4                                                                                 False
# ..                                                                                  ...
# 266                                                                               False
# 267                                                                               False
# 268                                                                               False
# 269                                                                               False
# 270                                                                               False
#
#      ALGORITHMIQUE MODERNE ANALYSE ET COMPLEXITE  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ..                                           ...
# 266                                        False
# 267                                        False
# 268                                        False
# 269                                        False
# 270                                        False
#
#      ANALYS CONCEPT ET CONTEXTES VOLUME 2 FONCTIONS DE PLUSIEURS VARIABLES  \
# 0                                                                    False
# 1                                                                    False
# 2                                                                    False
# 3                                                                    False
# 4                                                                    False
# ..                                                                     ...
# 266                                                                  False
# 267                                                                  False
# 268                                                                  False
# 269                                                                  False
# 270                                                                  False
#
#      ANALYSE 2 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS  \
# 0                                                     False
# 1                                                     False
# 2                                                     False
# 3                                                     False
# 4                                                     False
# ..                                                      ...
# 266                                                   False
# 267                                                   False
# 268                                                   False
# 269                                                   False
# 270                                                   False
#
#      ANALYSE FONCTIONS DE PLUSIEURS VARIABLES ET GEOMETRIE ANALYTIQUE  \
# 0                                                               False
# 1                                                               False
# 2                                                               False
# 3                                                               False
# 4                                                               False
# ..                                                                ...
# 266                                                             False
# 267                                                             False
# 268                                                             False
# 269                                                             False
# 270                                                             False
#
#      ANALYSE II POUR ECONOMISTES MANUEL D EXERCICES CORRIGES AVEC RAPPELS DE COURS INTEGRALES DOUBLES EQUATIONS DIFFERENTIELLES  \
# 0                                                                                                                         False
# 1                                                                                                                         False
# 2                                                                                                                         False
# 3                                                                                                                         False
# 4                                                                                                                         False
# ..                                                                                                                          ...
# 266                                                                                                                       False
# 267                                                                                                                       False
# 268                                                                                                                       False
# 269                                                                                                                       False
# 270                                                                                                                       False
#
#      ANALYSE MATHEMATIQUE EXERCICES CORRIGES  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 266                                    False
# 267                                    False
# 268                                     True
# 269                                    False
# 270                                    False
#
#      ANALYSE MP COURS METHODES ET EXERCICES CORRIGES  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ..                                               ...
# 266                                            False
# 267                                            False
# 268                                            False
# 269                                            False
# 270                                            False
#
#      ANALYSE PC PSI PT 2E ANNEE COURS ET 800 EXERCICES CORRIGES  \
# 0                                                         False
# 1                                                         False
# 2                                                         False
# 3                                                         False
# 4                                                         False
# ..                                                          ...
# 266                                                       False
# 267                                                       False
# 268                                                       False
# 269                                                       False
# 270                                                       False
#
#      ANATOMIE ET PHYSIOLOGIE HUMAINES  ANT COLONY OPTIMIZATION  \
# 0                               False                    False
# 1                               False                    False
# 2                               False                    False
# 3                               False                    False
# 4                               False                    False
# ..                                ...                      ...
# 266                             False                    False
# 267                             False                    False
# 268                             False                    False
# 269                             False                    False
# 270                             False                    False
#
#      APPRENDRE JAVA ET C EN PARALLELE  APPRENDRE LE C  \
# 0                               False           False
# 1                               False           False
# 2                               False           False
# 3                               False           False
# 4                               False           False
# ..                                ...             ...
# 266                             False           False
# 267                             False           False
# 268                             False           False
# 269                             False           False
# 270                             False           False
#
#      ARCHITECTURE ET TECHNOLOGIE DES ORDINATEURS  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ..                                           ...
# 266                                        False
# 267                                        False
# 268                                        False
# 269                                        False
# 270                                        False
#
#      ARTIFICIAL INTELLIGENCE AND MACHINE LEARNING IN 2D 3D MEDICAL IMAGE PROCESSING  \
# 0                                                                             False
# 1                                                                             False
# 2                                                                             False
# 3                                                                             False
# 4                                                                             False
# ..                                                                              ...
# 266                                                                           False
# 267                                                                           False
# 268                                                                           False
# 269                                                                           False
# 270                                                                           False
#
#      ARTIFICIAL INTELLIGENCE WITH AN INTRODUCTION TO MACHINE LEARNING  \
# 0                                                               False
# 1                                                               False
# 2                                                               False
# 3                                                               False
# 4                                                               False
# ..                                                                ...
# 266                                                             False
# 267                                                             False
# 268                                                             False
# 269                                                             False
# 270                                                             False
#
#      BASES DE DONNEES  BASES DE DONNEES CONCEPTS UTILISATION ET DEVELOPPEMENT  \
# 0               False                                                   False
# 1               False                                                   False
# 2               False                                                   False
# 3               False                                                   False
# 4               False                                                   False
# ..                ...                                                     ...
# 266             False                                                   False
# 267             False                                                   False
# 268             False                                                   False
# 269             False                                                   False
# 270             False                                                   False
#
#      BIG DATA ANALYTICS WITH APPLICATIONS IN INSIDER THREAT DETECTION      C  \
# 0                                                               False  False
# 1                                                               False  False
# 2                                                               False  False
# 3                                                                True  False
# 4                                                               False  False
# ..                                                                ...    ...
# 266                                                             False  False
# 267                                                             False  False
# 268                                                             False  False
# 269                                                             False  False
# 270                                                             False  False
#
#      C C LA BIBLE DU PROGRAMMEUR 1500 ASTUCES POUR TOUTES LES SITUATIONS  \
# 0                                                                  False
# 1                                                                  False
# 2                                                                  False
# 3                                                                  False
# 4                                                                  False
# ..                                                                   ...
# 266                                                                False
# 267                                                                False
# 268                                                                False
# 269                                                                False
# 270                                                                False
#
#      CALCUL DES PROBABILITES COURS EXERCICES ET PROBLEMES CORRIGES  \
# 0                                                            False
# 1                                                            False
# 2                                                            False
# 3                                                            False
# 4                                                            False
# ..                                                             ...
# 266                                                          False
# 267                                                          False
# 268                                                          False
# 269                                                          False
# 270                                                          False
#
#      CALCUL DIFFERENTIEL DES FONCTIONS DE PLUSIEURS VARIABLES  \
# 0                                                       False
# 1                                                       False
# 2                                                       False
# 3                                                       False
# 4                                                       False
# ..                                                        ...
# 266                                                     False
# 267                                                     False
# 268                                                     False
# 269                                                     False
# 270                                                     False
#
#      CALCUL DIFFERENTIEL ET INTEGRAL TOME 01  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 266                                    False
# 267                                    False
# 268                                    False
# 269                                    False
# 270                                    False
#
#      CAMBRIDGE ENGLISH SKILLS REAL LISTENING AND SPEAKING 1  \
# 0                                                     False
# 1                                                     False
# 2                                                     False
# 3                                                     False
# 4                                                      True
# ..                                                      ...
# 266                                                   False
# 267                                                   False
# 268                                                   False
# 269                                                   False
# 270                                                   False
#
#      CAMBRIDGE ENGLISH SKILLS REAL LISTENING AND SPEAKING 2  \
# 0                                                     False
# 1                                                     False
# 2                                                     False
# 3                                                     False
# 4                                                      True
# ..                                                      ...
# 266                                                   False
# 267                                                   False
# 268                                                   False
# 269                                                   False
# 270                                                   False
#
#      CHAINES DE MARKOV COURS EXERCICES ET CORRIGES DETAILLES  \
# 0                                                      False
# 1                                                      False
# 2                                                      False
# 3                                                      False
# 4                                                      False
# ..                                                       ...
# 266                                                    False
# 267                                                    False
# 268                                                    False
# 269                                                    False
# 270                                                    False
#
#      COMMENT PROGRAMMER EN C  COMPUTER NETWORKING A TOP DOWN APPROACH  \
# 0                      False                                    False
# 1                      False                                    False
# 2                      False                                    False
# 3                      False                                    False
# 4                      False                                    False
# ..                       ...                                      ...
# 266                    False                                    False
# 267                    False                                    False
# 268                    False                                    False
# 269                    False                                    False
# 270                    False                                    False
#
#      COMPUTER ORGANIZATION AND ARCHITECTURE DESIGNING FOR PERFORMANCE GLOBAL EDITION  \
# 0                                                                              False
# 1                                                                              False
# 2                                                                              False
# 3                                                                              False
# 4                                                                               True
# ..                                                                               ...
# 266                                                                            False
# 267                                                                            False
# 268                                                                            False
# 269                                                                            False
# 270                                                                            False
#
#      COMPUTER VISION A MODERN APPROACH  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ..                                 ...
# 266                              False
# 267                              False
# 268                              False
# 269                              False
# 270                              False
#
#      COMPUTER VISION ALGORITHMS AND APPLICATIONS ALGORITHMS AND APPLICATIONS  \
# 0                                                                      False
# 1                                                                      False
# 2                                                                      False
# 3                                                                      False
# 4                                                                      False
# ..                                                                       ...
# 266                                                                    False
# 267                                                                    False
# 268                                                                    False
# 269                                                                    False
# 270                                                                    False
#
#      COURS D ALGEBRE ET EXERCICES CORRIGES  COURS ELEMENTAIRE DE TOPOGRAPHIE  \
# 0                                    False                             False
# 1                                    False                             False
# 2                                    False                             False
# 3                                    False                             False
# 4                                    False                             False
# ..                                     ...                               ...
# 266                                  False                             False
# 267                                  False                             False
# 268                                   True                             False
# 269                                  False                             False
# 270                                  False                             False
#
#      DATABASE SYSTEMS DESIGN IMPLEMENTATION MANAGEMENT  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 266                                              False
# 267                                              False
# 268                                              False
# 269                                               True
# 270                                              False
#
#      DE L ALGEBRE DE BOOLE AUX CIRCUITS NUMERIQUES COURS ET APPLICATIONS  \
# 0                                                                  False
# 1                                                                  False
# 2                                                                  False
# 3                                                                  False
# 4                                                                  False
# ..                                                                   ...
# 266                                                                False
# 267                                                                False
# 268                                                                False
# 269                                                                False
# 270                                                                False
#
#      DE MES CAHIERS D ANALYSE EQUATIONS DIFFERENTIELLES ORDINAIRES DU PREMIER ET SECOND ORDRE ASSISE THEORIQUE ET APPLICATIONS COURS DETAILLE ET EXERCICES RESOLUS  \
# 0                                                                                                                                                            False
# 1                                                                                                                                                            False
# 2                                                                                                                                                            False
# 3                                                                                                                                                            False
# 4                                                                                                                                                            False
# ..                                                                                                                                                             ...
# 266                                                                                                                                                          False
# 267                                                                                                                                                          False
# 268                                                                                                                                                          False
# 269                                                                                                                                                          False
# 270                                                                                                                                                          False
#
#      DE MES CAHIERS D ANALYSE FONCTIONS REELLES D UNE VARIABLE REELLE LIMITES CONTINUITE ET COURS DETAILLE ET EXERCICES RESOLUS  \
# 0                                                                                                                         False
# 1                                                                                                                         False
# 2                                                                                                                         False
# 3                                                                                                                         False
# 4                                                                                                                         False
# ..                                                                                                                          ...
# 266                                                                                                                       False
# 267                                                                                                                       False
# 268                                                                                                                       False
# 269                                                                                                                       False
# 270                                                                                                                       False
#
#      DE MES CAHIERS D ANALYSE INTEGRALE DE RIEMANN CALCUL DE PRIMITIVES INTEGRALES IMPROPRES COURS DETAILLE ET EXERCICES RESOLUS  \
# 0                                                                                                                          False
# 1                                                                                                                          False
# 2                                                                                                                          False
# 3                                                                                                                          False
# 4                                                                                                                          False
# ..                                                                                                                           ...
# 266                                                                                                                        False
# 267                                                                                                                        False
# 268                                                                                                                        False
# 269                                                                                                                        False
# 270                                                                                                                        False
#
#      DE MES CAHIERS D ANALYSE SUITES NUMERIQUES COURS DETAILLE ET EXERCICES RESOLUS  \
# 0                                                                             False
# 1                                                                             False
# 2                                                                             False
# 3                                                                             False
# 4                                                                             False
# ..                                                                              ...
# 266                                                                           False
# 267                                                                           False
# 268                                                                           False
# 269                                                                           False
# 270                                                                           False
#
#      DEEP LEARNING WITH PYTHON  \
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ..                         ...
# 266                      False
# 267                      False
# 268                      False
# 269                      False
# 270                      False
#
#      DEVELOPPER DES BASES DE DONNEES WEB AVEC LA PLATEFORME NET ETAPE PAR ETAPE  \
# 0                                                                         False
# 1                                                                         False
# 2                                                                         False
# 3                                                                         False
# 4                                                                         False
# ..                                                                          ...
# 266                                                                       False
# 267                                                                       False
# 268                                                                       False
# 269                                                                       False
# 270                                                                       False
#
#      EFFECTIVE MODERN C 42 SPECIFIC WAYS TO IMPROVE YOUR USE OF C 11 AND C 14  \
# 0                                                                       False
# 1                                                                       False
# 2                                                                       False
# 3                                                                       False
# 4                                                                       False
# ..                                                                        ...
# 266                                                                     False
# 267                                                                     False
# 268                                                                     False
# 269                                                                     False
# 270                                                                     False
#
#      ELEMENTS D ANALYSE NUMERIQUE  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ..                            ...
# 266                         False
# 267                         False
# 268                         False
# 269                         False
# 270                         False
#
#      ELEMENTS DE LA THEORIE DES PROBABILITES T 1  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ..                                           ...
# 266                                        False
# 267                                        False
# 268                                        False
# 269                                        False
# 270                                        False
#
#      ELEMENTS DE LA THEORIE DES PROBABILITES T 2  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ..                                           ...
# 266                                        False
# 267                                        False
# 268                                        False
# 269                                        False
# 270                                        False
#
#      EXERCICES CORRIGES D ALGEBRE  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# ...
# 0              False                                                   False
# 1              False                                                   False
# 2              False                                                   False
# 3              False                                                   False
# 4              False                                                   False
# ..               ...                                                     ...
# 266            False                                                   False
# 267            False                                                   False
# 268            False                                                   False
# 269            False                                                   False
# 270            False                                                   False
#
#      PYTHON POUR LE DATA SCIENTIST DES BASES DU LANGAGE AU MACHINE LEARNING  \
# 0                                                                     False
# 1                                                                     False
# 2                                                                     False
# 3                                                                     False
# 4                                                                     False
# ..                                                                      ...
# 266                                                                   False
# 267                                                                   False
# 268                                                                   False
# 269                                                                   False
# 270                                                                   False
#
#      RECHERCHE OPERATIONNELLE POUR INGENIEURS 2  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ..                                          ...
# 266                                       False
# 267                                       False
# 268                                       False
# 269                                       False
# 270                                       False
#
#      REINFORCEMENT LEARNING AN INTRODUCTION  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ..                                      ...
# 266                                   False
# 267                                   False
# 268                                   False
# 269                                    True
# 270                                   False
#
#      RESEAUX INFORMATIQUES RECUEIL DE SUJETS D EXAMENS AVEC SOLUTIONS  \
# 0                                                               False
# 1                                                               False
# 2                                                               False
# 3                                                               False
# 4                                                               False
# ..                                                                ...
# 266                                                             False
# 267                                                             False
# 268                                                             False
# 269                                                             False
# 270                                                             False
#
#      S E M 300 PAR SES EXAMENS T 1 ANALYSE ET ALGEBRE DE PREMIERE ANNEE DES UNIVERSITES ET GRANDES ECOLES SCIENTIFIQUES  \
# 0                                                                                                                 False
# 1                                                                                                                 False
# 2                                                                                                                 False
# 3                                                                                                                 False
# 4                                                                                                                 False
# ..                                                                                                                  ...
# 266                                                                                                               False
# 267                                                                                                               False
# 268                                                                                                               False
# 269                                                                                                               False
# 270                                                                                                               False
#
#      S E M 300 PAR SES EXAMENS TOME2 ANALYSE ET ALGEBRE DE PREMIERE ANNEE DES UNIVERSITES ET GRNDES ECOLES SCIENTIFIQUES  \
# 0                                                                                                                  False
# 1                                                                                                                  False
# 2                                                                                                                  False
# 3                                                                                                                  False
# 4                                                                                                                  False
# ..                                                                                                                   ...
# 266                                                                                                                False
# 267                                                                                                                False
# 268                                                                                                                False
# 269                                                                                                                False
# 270                                                                                                                False
#
#      SIMULATION NUMERIQUE EN C COURS ET EXERCICES CORRIGES  \
# 0                                                    False
# 1                                                    False
# 2                                                    False
# 3                                                    False
# 4                                                    False
# ..                                                     ...
# 266                                                  False
# 267                                                  False
# 268                                                  False
# 269                                                  False
# 270                                                  False
#
#      SOFTWARE ENGINEERING  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ..                    ...
# 266                 False
# 267                 False
# 268                 False
# 269                 False
# 270                 False
#
#      STATISTIQUE COURS ET EXERCICES POUR LES ETUDIANTS DU TRONC COMMUN BIO MEDICAL  \
# 0                                                                            False
# 1                                                                            False
# 2                                                                            False
# 3                                                                            False
# 4                                                                            False
# ..                                                                             ...
# 266                                                                          False
# 267                                                                          False
# 268                                                                          False
# 269                                                                          False
# 270                                                                          False
#
#      STRUCTURE DES ORDINATEURS AUTOUR DU PROCESSEUR  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
# ..                                              ...
# 266                                           False
# 267                                           False
# 268                                           False
# 269                                           False
# 270                                           False
#
#      SUPERINTELLIGENCE PATHS DANGERS STRATEGIES  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ..                                          ...
# 266                                       False
# 267                                       False
# 268                                       False
# 269                                       False
# 270                                       False
#
#      THE HUNDRED PAGE MACHINE LEARNING BOOK  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ..                                      ...
# 266                                   False
# 267                                   False
# 268                                   False
# 269                                   False
# 270                                   False
#
#      TOUT LE PROGRAMME DE MATHEMATIQUE EN BCPTI 1 AVEC 1000 EXERCICES ET PROBLEMES  \
# 0                                                                            False
# 1                                                                            False
# 2                                                                            False
# 3                                                                            False
# 4                                                                            False
# ..                                                                             ...
# 266                                                                          False
# 267                                                                          False
# 268                                                                          False
# 269                                                                          False
# 270                                                                          False
#
#      TOUT SUR R ENSEMBLE DES NOMBRES REELS STRUCTURES ALGEBRIQUE ET TOPOLOGIQUE  \
# 0                                                                         False
# 1                                                                         False
# 2                                                                         False
# 3                                                                         False
# 4                                                                         False
# ..                                                                          ...
# 266                                                                       False
# 267                                                                       False
# 268                                                                       False
# 269                                                                       False
# 270                                                                       False
#
#      TOUTES LES MATHEMATIQUES MP 1RE PARTIE LE KIT DE SURVIE 2E PARTIE DES CERISES SUR LE GATEAU  \
# 0                                                                                          False
# 1                                                                                          False
# 2                                                                                          False
# 3                                                                                          False
# 4                                                                                          False
# ..                                                                                           ...
# 266                                                                                        False
# 267                                                                                        False
# 268                                                                                        False
# 269                                                                                        False
# 270                                                                                        False
#
#      UNDERSTANDING ANALYSIS  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ..                      ...
# 266                   False
# 267                   False
# 268                   False
# 269                   False
# 270                   False
#
#      WIRELESS MEDICAL SYSTEMS AND ALGORITHMS DESIGN AND APPLICATIONS  \
# 0                                                              False
# 1                                                              False
# 2                                                              False
# 3                                                              False
# 4                                                              False
# ..                                                               ...
# 266                                                            False
# 267                                                            False
# 268                                                            False
# 269                                                            False
# 270                                                            False
#
#      مهارات التفكير النقدي لدى طلاب الجامعات العربية
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ..                                               ...
# 266                                            False
# 267                                            False
# 268                                            False
# 269                                            False
# 270                                            False
#
# [271 rows x 133 columns]

# %%
frequent_itemsets_fpg=fpgrowth(borrowing_df, min_support=0.01)
frequent_itemsets_fpg
# Out:
#      support   itemsets
# 0   0.018450       (90)
# 1   0.011070       (87)
# 2   0.011070       (75)
# 3   0.199262       (68)
# 4   0.011070       (80)
# 5   0.014760       (35)
# 6   0.025830       (69)
# 7   0.014760       (53)
# 8   0.066421      (110)
# 9   0.033210       (96)
# 10  0.022140       (18)
# 11  0.022140       (61)
# 12  0.018450       (59)
# 13  0.011070       (60)
# 14  0.018450       (77)
# 15  0.210332       (47)
# 16  0.018450        (6)
# 17  0.014760       (13)
# 18  0.022140       (54)
# 19  0.011070       (42)
# 20  0.011070      (120)
# 21  0.202952        (5)
# 22  0.018450       (66)
# 23  0.014760       (50)
# 24  0.014760      (119)
# 25  0.011070       (15)
# 26  0.033210      (128)
# 27  0.011070       (64)
# 28  0.011070       (21)
# 29  0.040590  (68, 110)
# 30  0.011070    (96, 5)
# 31  0.011070   (59, 68)
# 32  0.059041    (5, 47)
# 33  0.011070    (66, 5)
# 34  0.018450   (128, 5)

# %%
frequent_itemsets_apr=apriori(borrowing_df, min_support=0.01)
frequent_itemsets_apr
# Out:
#      support   itemsets
# 0   0.202952        (5)
# 1   0.018450        (6)
# 2   0.014760       (13)
# 3   0.011070       (15)
# 4   0.022140       (18)
# 5   0.011070       (21)
# 6   0.014760       (35)
# 7   0.011070       (42)
# 8   0.210332       (47)
# 9   0.014760       (50)
# 10  0.014760       (53)
# 11  0.022140       (54)
# 12  0.018450       (59)
# 13  0.011070       (60)
# 14  0.022140       (61)
# 15  0.011070       (64)
# 16  0.018450       (66)
# 17  0.199262       (68)
# 18  0.025830       (69)
# 19  0.011070       (75)
# 20  0.018450       (77)
# 21  0.011070       (80)
# 22  0.011070       (87)
# 23  0.018450       (90)
# 24  0.033210       (96)
# 25  0.066421      (110)
# 26  0.014760      (119)
# 27  0.011070      (120)
# 28  0.033210      (128)
# 29  0.059041    (5, 47)
# 30  0.011070    (66, 5)
# 31  0.011070    (96, 5)
# 32  0.018450   (128, 5)
# 33  0.011070   (59, 68)
# 34  0.040590  (68, 110)

# %% [markdown]
# ### Generate Rules

# %%
# Make sure you use use_colnames=True to get actual book titles
frequent_itemsets_fpg = fpgrowth(borrowing_df, min_support=0.01, use_colnames=True)
frequent_itemsets_apr = apriori(borrowing_df, min_support=0.01, use_colnames=True)

rules_fpg=association_rules(frequent_itemsets_fpg, metric="confidence", min_threshold=0.01)
rules_apr=association_rules(frequent_itemsets_apr, metric="confidence", min_threshold=0.01)
rules_fpg
# Out:
#                                                                                                              antecedents  \
# 0   (FONCTIONS DE PLUSIEURS VARIABLES RELLES IMITES CONTINUITE DIFFERENTIABILITE ET COURS DETAILLE ET EXERCICES RESOLUS)
# 1                                                                  (PROBABILITES RAPPELS DE COURS ET EXERCICES CORRIGES)
# 2                                                                     (MATHEMATIQUES RAPPELS ET COURS EXERCICES RESOLUS)
# 3                                                               (ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS)
# 4   (FONCTIONS DE PLUSIEURS VARIABLES RELLES IMITES CONTINUITE DIFFERENTIABILITE ET COURS DETAILLE ET EXERCICES RESOLUS)
# 5                                                                          (ELEMENTS DE LA THEORIE DES PROBABILITES T 1)
# 6                                                                                (COURS D ALGEBRE ET EXERCICES CORRIGES)
# 7                                                               (ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS)
# 8                                                                        (EXERCICES EN LANGAGE C 178 EXERCICES CORRIGES)
# 9                                                               (ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS)
# 10                                          (TOUT SUR R ENSEMBLE DES NOMBRES REELS STRUCTURES ALGEBRIQUE ET TOPOLOGIQUE)
# 11                                                              (ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS)
#
#                                                                                                              consequents  \
# 0                                                                  (PROBABILITES RAPPELS DE COURS ET EXERCICES CORRIGES)
# 1   (FONCTIONS DE PLUSIEURS VARIABLES RELLES IMITES CONTINUITE DIFFERENTIABILITE ET COURS DETAILLE ET EXERCICES RESOLUS)
# 2                                                               (ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS)
# 3                                                                     (MATHEMATIQUES RAPPELS ET COURS EXERCICES RESOLUS)
# 4                                                                          (ELEMENTS DE LA THEORIE DES PROBABILITES T 1)
# 5   (FONCTIONS DE PLUSIEURS VARIABLES RELLES IMITES CONTINUITE DIFFERENTIABILITE ET COURS DETAILLE ET EXERCICES RESOLUS)
# 6                                                               (ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS)
# 7                                                                                (COURS D ALGEBRE ET EXERCICES CORRIGES)
# 8                                                               (ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS)
# 9                                                                        (EXERCICES EN LANGAGE C 178 EXERCICES CORRIGES)
# 10                                                              (ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS)
# 11                                          (TOUT SUR R ENSEMBLE DES NOMBRES REELS STRUCTURES ALGEBRIQUE ET TOPOLOGIQUE)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.199262            0.066421  0.040590    0.203704  3.066872
# 1             0.066421            0.199262  0.040590    0.611111  3.066872
# 2             0.033210            0.202952  0.011070    0.333333  1.642424
# 3             0.202952            0.033210  0.011070    0.054545  1.642424
# 4             0.199262            0.018450  0.011070    0.055556  3.011111
# 5             0.018450            0.199262  0.011070    0.600000  3.011111
# 6             0.210332            0.202952  0.059041    0.280702  1.383094
# 7             0.202952            0.210332  0.059041    0.290909  1.383094
# 8             0.018450            0.202952  0.011070    0.600000  2.956364
# 9             0.202952            0.018450  0.011070    0.054545  2.956364
# 10            0.033210            0.202952  0.018450    0.555556  2.737374
# 11            0.202952            0.033210  0.018450    0.090909  2.737374
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 0                1.0  0.027355    1.172402       0.841642  0.180328
# 1                1.0  0.027355    2.059041       0.721883  0.180328
# 2                1.0  0.004330    1.195572       0.404580  0.049180
# 3                1.0  0.004330    1.022566       0.490741  0.049180
# 4                1.0  0.007394    1.039288       0.834101  0.053571
# 5                1.0  0.007394    2.001845       0.680451  0.053571
# 6                1.0  0.016353    1.108091       0.350759  0.166667
# 7                1.0  0.016353    1.113634       0.347512  0.166667
# 8                1.0  0.007326    1.992620       0.674185  0.052632
# 9                1.0  0.007326    1.038178       0.830247  0.052632
# 10               1.0  0.011710    1.793358       0.656489  0.084746
# 11               1.0  0.011710    1.063469       0.796296  0.084746
#
#     certainty  kulczynski
# 0    0.147050    0.407407
# 1    0.514337    0.407407
# 2    0.163580    0.193939
# 3    0.022068    0.193939
# 4    0.037803    0.327778
# 5    0.500461    0.327778
# 6    0.097547    0.285805
# 7    0.102039    0.285805
# 8    0.498148    0.327273
# 9    0.036774    0.327273
# 10   0.442387    0.323232
# 11   0.059681    0.323232

# %%
# ============================================================================
# STEP 2: Display rules with actual book titles
# ============================================================================

def show_rules(rules_df):
    """Display association rules in readable format with book titles"""
    print(f"\nTotal Rules: {len(rules_df)}")
    print("="*100)
    
    for idx, row in rules_df.iterrows():
        # Get the actual book titles from antecedents and consequents
        antecedents_books = list(row['antecedents'])
        consequents_books = list(row['consequents'])
        
        print(f"\nRule {idx+1}:")
        print(f"  IF a reader borrows:")
        for book in antecedents_books:
            print(f"    - {book}")
        print(f"  THEN they will also borrow:")
        for book in consequents_books:
            print(f"    - {book}")
        print(f"\n  Metrics:")
        print(f"    Support: {row['support']:.2%} | Confidence: {row['confidence']:.2%} | Lift: {row['lift']:.2f}")
        print("-"*100)

# Use it:
show_rules(rules_apr)
# Out:
# Total Rules: 12
# ====================================================================================================
#
# Rule 1:
#   IF a reader borrows:
#     - COURS D ALGEBRE ET EXERCICES CORRIGES
#   THEN they will also borrow:
#     - ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS
#
#   Metrics:
#     Support: 5.90% | Confidence: 28.07% | Lift: 1.38
# ----------------------------------------------------------------------------------------------------
#
# Rule 2:
#   IF a reader borrows:
#     - ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS
#   THEN they will also borrow:
#     - COURS D ALGEBRE ET EXERCICES CORRIGES
#
#   Metrics:
#     Support: 5.90% | Confidence: 29.09% | Lift: 1.38
# ----------------------------------------------------------------------------------------------------
#
# Rule 3:
#   IF a reader borrows:
#     - EXERCICES EN LANGAGE C 178 EXERCICES CORRIGES
#   THEN they will also borrow:
#     - ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS
#
#   Metrics:
#     Support: 1.11% | Confidence: 60.00% | Lift: 2.96
# ----------------------------------------------------------------------------------------------------
#
# Rule 4:
#   IF a reader borrows:
#     - ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS
#   THEN they will also borrow:
#     - EXERCICES EN LANGAGE C 178 EXERCICES CORRIGES
#
#   Metrics:
#     Support: 1.11% | Confidence: 5.45% | Lift: 2.96
# ----------------------------------------------------------------------------------------------------
#
# Rule 5:
#   IF a reader borrows:
#     - MATHEMATIQUES RAPPELS ET COURS EXERCICES RESOLUS
#   THEN they will also borrow:
#     - ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS
#
#   Metrics:
#     Support: 1.11% | Confidence: 33.33% | Lift: 1.64
# ----------------------------------------------------------------------------------------------------
#
# Rule 6:
#   IF a reader borrows:
#     - ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS
#   THEN they will also borrow:
#     - MATHEMATIQUES RAPPELS ET COURS EXERCICES RESOLUS
#
#   Metrics:
#     Support: 1.11% | Confidence: 5.45% | Lift: 1.64
# ----------------------------------------------------------------------------------------------------
#
# Rule 7:
#   IF a reader borrows:
#     - TOUT SUR R ENSEMBLE DES NOMBRES REELS STRUCTURES ALGEBRIQUE ET TOPOLOGIQUE
#   THEN they will also borrow:
#     - ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS
#
#   Metrics:
#     Support: 1.85% | Confidence: 55.56% | Lift: 2.74
# ----------------------------------------------------------------------------------------------------
#
# Rule 8:
#   IF a reader borrows:
#     - ALGEBRE 1 RAPPELS DE COURS ET EXERCICES AVEC SOLUTIONS
#   THEN they will also borrow:
#     - TOUT SUR R ENSEMBLE DES NOMBRES REELS STRUCTURES ALGEBRIQUE ET TOPOLOGIQUE
#
#   Metrics:
#     Support: 1.85% | Confidence: 9.09% | Lift: 2.74
# ----------------------------------------------------------------------------------------------------
#
# Rule 9:
#   IF a reader borrows:
#     - FONCTIONS DE PLUSIEURS VARIABLES RELLES IMITES CONTINUITE DIFFERENTIABILITE ET COURS DETAILLE ET EXERCICES RESOLUS
#   THEN they will also borrow:
#     - ELEMENTS DE LA THEORIE DES PROBABILITES T 1
#
#   Metrics:
#     Support: 1.11% | Confidence: 5.56% | Lift: 3.01
# ----------------------------------------------------------------------------------------------------
#
# Rule 10:
#   IF a reader borrows:
#     - ELEMENTS DE LA THEORIE DES PROBABILITES T 1
#   THEN they will also borrow:
#     - FONCTIONS DE PLUSIEURS VARIABLES RELLES IMITES CONTINUITE DIFFERENTIABILITE ET COURS DETAILLE ET EXERCICES RESOLUS
#
#   Metrics:
#     Support: 1.11% | Confidence: 60.00% | Lift: 3.01
# ----------------------------------------------------------------------------------------------------
#
# Rule 11:
#   IF a reader borrows:
#     - FONCTIONS DE PLUSIEURS VARIABLES RELLES IMITES CONTINUITE DIFFERENTIABILITE ET COURS DETAILLE ET EXERCICES RESOLUS
#   THEN they will also borrow:
#     - PROBABILITES RAPPELS DE COURS ET EXERCICES CORRIGES
#
#   Metrics:
#     Support: 4.06% | Confidence: 20.37% | Lift: 3.07
# ----------------------------------------------------------------------------------------------------
#
# Rule 12:
#   IF a reader borrows:
#     - PROBABILITES RAPPELS DE COURS ET EXERCICES CORRIGES
#   THEN they will also borrow:
#     - FONCTIONS DE PLUSIEURS VARIABLES RELLES IMITES CONTINUITE DIFFERENTIABILITE ET COURS DETAILLE ET EXERCICES RESOLUS
#
#   Metrics:
#     Support: 4.06% | Confidence: 61.11% | Lift: 3.07
# ----------------------------------------------------------------------------------------------------
